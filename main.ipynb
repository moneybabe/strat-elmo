# %%
from main import *

# %%
df = export_close_order(scan_order(crop_image("images/image2.jpeg")))
df
# Out:
#   Contracts Closing Direction        Qty  Entry Price  Exit Price  \
# 0   BTCUSDT        Close Long  0.677 BTC     29914.20    30684.90
# 1   ETHUSDT        Close Long   2.13 ETH      1934.37     2103.98
# 2   ETHUSDT        Close Long  20.00 ETH      1934.37     2103.24
# 3   ETHUSDT        Close Long   4.81 ETH      1934.37     2108.15
# 4   ETHUSDT        Close Long   9.06 ETH      1934.37     2118.19
# 5   ETHUSDT        Close Long   7.63 ETH      1934.37     2114.30
# 6   ETHUSDT        Close Long  12.71 ETH      1934.37     2107.46
# 7   BTCUSDT        Close Long  1.326 BTC     29914.20    30707.80
# 8   BTCUSDT        Close Long  0.590 BTC     29914.20    30780.40
# 9   ETHUSDT        Close Long  47.71 ETH      1934.37     2122.80
#
#     Closed P&L Exit Type           Trade Time
# 0   510.379504     Trade  2023-04-14 08:46:58
# 1   189.669408     Trade  2023-04-14 08:46:46
# 2  3359.013244     Trade  2023-04-14 08:46:46
# 3   831.458604     Trade  2023-04-14 08:45:08
# ...
